# %%
import streamlit as st
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import mean_squared_error, r2_score
 
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()


df = pd.read_csv('Financial_inclusion_dataset.csv')

# Define the input features (replace with your actual feature names)
def user_input_options():
    country = st.selectbox(df['country'].unique())
    options = {'Kenya':0, 'Rwanda':1, 'Tanzania':2, 'Uganda':3}
    age_of_respondent = st.number_input('age_of_respondent', min_value=16, max_value=100)
    gender_of_respondent = st.selectbox(df['gender_of_respondent'].unique())
    options = {"Female":0, "Male":1}
    education_level = st.selectbox(df['education_level'].unique())
    options = {'Secondary education':0, 'No formal education':1, 'Vocational/Specialised training':2, 'Primary education':3, 'Tertiary education':4, 'Other/Dont know/RTA':5}
    job_type = st.selectbox(df['job_type'].unique())
    options = {'Self employed':0, 'Government Dependent':1, 'Formally employed Private':2, 'Informally employed':3, 'Formally employed Government':4, 'Farming and Fishing':5, 'Remittance Dependent':6, 'Other Income':7, 'Dont Know/Refuse to answer':8, 'No Income':9}
    bank_account = st.selectbox(df['bank_account'].unique())
    options = {'Yes':1, 'No':0}
    uniqueid = st.number_input('uniqueid', min_value=1, max_value=8759)
    location_type = st.selectbox(df['location_type'].unique())
    options = {'Rural':1, 'Urban':0}
    cellphone_access = st.selectbox(df['cellphone_access'].unique())
    options = {'Yes':1, 'No':0}
    household_size = st.number_input('household_size', min_value=1, max_value=21)
    relationship_with_head = st.selectbox(df['relationship_with_head'].unique())
    options = {'Spouse':0, 'Head of Household':1, 'Other relative':2, 'Child':3, 'Parent':4, 'Other non-relatives':5}
    marital_status = st.selectbox(df['marital_status'].unique())
    options = {'Married/Living together':0, 'Widowed':1, 'Single/Never Married':2, 'Divorced/Seperated':3, 'Dont know':4}
    year = st.number_input('year', min_value=2016, max_value=2018)
    
    
    
    

    data = {
        'age_of_respondent': age,
        'gender_of_respondent': gender_of_respondent,
        'education_level': education_level,
        'country': country,
        'job_type': job_type,
        'bank_account': bank_account,
        'uniqueid': uniqueid,
        'location_type': location_type,
        'cellphone_access': cellphone_access,
        'household_size': household_size,
        'relationship_with_head': relationship_with_head,
        'year': year,
        'marital_status': marital_status
    }
    options = pd.DataFrame(data, index=[0])
    return options

st.title('Financial Inclusion in Africa - Individual Bank Account Prediction')

st.sidebar.header('Input Features')

input_df = user_input_options()

if st.button('Predict'):
    
    input_scaled = scaler.transform(input_df)
    prediction = model.predict(input_scaled)
    prediction_proba = model.predict_proba(input_scaled)

    if prediction[0] == 1:
        st.success('The individual is likely to have a bank account.')
    else:
        st.warning('The individual is unlikely to have a bank account.')

    st.write(f"Prediction Probability: {prediction_proba}")

# %%
import pickle
